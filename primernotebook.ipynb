# %%
print ('hola mundo')
print ('otra cosa')
# Out:
# hola mundo
# otra cosa

# %% [markdown]
# # COemntarios

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3,4,5,6,7,8,9]
b = [1.,4,9,16,25,36,49,64,81]

# %%
plt.plot(a,b)
plt.show()
